# %% [markdown]
# Pandas Profiling is used for automatically analyzes your dataset and gives a full report.

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.datasets import load_diabetes

# %%
data = load_diabetes()

df = pd.DataFrame(data.data, columns=data.feature_names)

print(df.head())

# %%
profile = ProfileReport(df, title="Data Profiling Report")

profile.to_file("report.html")

profile.to_notebook_iframe()

# %% [markdown]
# Autoviz that automatically creates graphs and charts from your dataset.

# %% [markdown]
# Sweetviz is a tool that creates a beautiful visual report of your dataset. output is HTML file

# %% [markdown]
# D-Tale is used to To explore and manipulate data interactively and opens in browser through link
